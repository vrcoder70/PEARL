# %%
import pandas as pd
data = pd.read_csv('/Users/yashshah/ASU Documents/Fall 22/CSE 578 Data Visualisation/Project/Mukesh-Shubham-Tirth-Tirth-Vraj-Yash/yash-shah-code/ML Model/VADanalysis/outputs/2835653131.csv')
data
# Out:
#       Sentence ID                                           Sentence  \
# 0               1  ['the', 'confidence', 'you', 'lead', 'life', '...
# 1               2  ['the', 'person', 'who', '’', 's', 'voice', 'i...
# 2               3  ['tête', 'de', 'femme', 'no', '.', '2', ',', '...
# 3               4    ['then', 'working', 'on', 'self', 'betterment']
# 4               5  ['if', 'not', 'working', 'on', 'nurturing', 'r...
# ...           ...                                                ...
# 1250         1251                                                 []
# 1251         1252  ['twitter', 'can', 'be', 'the', 'new', 'water'...
# 1252         1253                                                 []
# 1253         1254                           ['bradley', 'beal', ':']
# 1254         1255  ['https', ':', '//t.co/mbxub7la9frt', '@', 'da...
#
#        Valence   Arousal  Dominance Sentiment Label  Average VAD  \
# 0     6.168372  4.121860   5.888372        positive     5.392868
# ...
